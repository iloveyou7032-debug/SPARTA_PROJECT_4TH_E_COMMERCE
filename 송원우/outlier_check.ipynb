# %%
# 데이터 처리 및 분석
import pandas as pd
import ast
import numpy as np
from datetime import datetime, timedelta
import warnings
import re

# 시각화
import matplotlib.pyplot as plt
import seaborn as sns

# 통계 분석
from scipy import stats
from scipy.stats import shapiro, levene, ttest_ind, chi2_contingency, f_oneway
from scipy.stats import mannwhitneyu, fisher_exact, kruskal
import scikit_posthocs as sp
from statsmodels.stats.multicomp import pairwise_tukeyhsd, MultiComparison
import pingouin as pg
import platform

# ── 한글 폰트 설정 ──
if platform.system() == 'Windows':
    plt.rcParams['font.family'] = 'Malgun Gothic'
elif platform.system() == 'Darwin':
    plt.rcParams['font.family'] = 'AppleGothic'
else:
    plt.rcParams['font.family'] = 'NanumGothic'

# ── 출력 설정 ──
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
np.random.seed(42)

# 시드 설정
np.random.seed(42)

print("="*60)
print("라이브러리 로드 완료!")
print("한글 폰트 설정 완료!")
print("=" * 60)
# Out:
# ...
# 라이브러리 로드 완료!
# 한글 폰트 설정 완료!
# ...

# %%
path = "/Users/wonwoo_mac/Desktop/SPARTA_PROJECT_4TH_E_COMMERCE/송원우/final_data/"

df = pd.read_csv(path + '젝시믹스_master.csv')
df.head()
# Out:
#   collect_date platform  review_id  product_id       product_name review_date  \
# 0   2026-04-20      자사몰  5032253.0     2070608  UV 쉴드 에어핏 페이스 마스크  2026-03-09
# 1   2026-04-20      자사몰  4998316.0     2070608  UV 쉴드 에어핏 페이스 마스크  2026-01-26
# 2   2026-04-20      자사몰  4936161.0     2070608  UV 쉴드 에어핏 페이스 마스크  2025-12-14
# 3   2026-04-20      자사몰  4727267.0     2070608  UV 쉴드 에어핏 페이스 마스크  2025-07-22
# 4   2026-04-20      자사몰  4821424.0     2070608  UV 쉴드 에어핏 페이스 마스크  2025-10-10
#
#    year  month                                            content  rating  \
# 0  2026      3  친구 소개로 구매했어요 친구가 걷기운동할때 필요해서 이것저것 구매했는데 기장 편하게...       5
# 1  2026      1  l사이즈 사고 원단도 좋고 운동시 호흡도 편한데 큰 느낌이라 작은사이즈 다시 주문했...       5
# 2  2025     12  구매하여 처음 사용해봤는데 가성비 진짜 좋네요 바람도 잘 막아주고 추운날씨에도 딱 ...       5
# 3  2025      7  전부터 풀페이스마스크 하나 사려고 보고 있다가 지난번 블랙색상 사고 마음에 들어서 ...       5
# 4  2025     10   낮에 러닝하는데 얼굴 타는게 신경쓰였는데 마스크 답답하지 않고 흘러 내리지 않아 좋아요       5
#
# ...

# %%
df_check = df[['review_id', 'review_date', 'product_name', 'year', 'month', 'rating', 'helpful_count', 'has_image', 'cat1', 'cat2', 'brand']].copy()
df_check.head()
# Out:
#    review_id review_date       product_name  year  month  rating  \
# 0  5032253.0  2026-03-09  UV 쉴드 에어핏 페이스 마스크  2026      3       5
# 1  4998316.0  2026-01-26  UV 쉴드 에어핏 페이스 마스크  2026      1       5
# 2  4936161.0  2025-12-14  UV 쉴드 에어핏 페이스 마스크  2025     12       5
# 3  4727267.0  2025-07-22  UV 쉴드 에어핏 페이스 마스크  2025      7       5
# 4  4821424.0  2025-10-10  UV 쉴드 에어핏 페이스 마스크  2025     10       5
#
#    helpful_count  has_image cat1 cat2 brand
# 0              1          1   용품   기타  젝시믹스
# 1              0          1   용품   기타  젝시믹스
# 2              0          1   용품   기타  젝시믹스
# 3              4          1   용품   기타  젝시믹스
# 4              1          1   용품   기타  젝시믹스

# %%
df_check.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 501893 entries, 0 to 501892
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   review_id      501893 non-null  float64
#  1   review_date    501893 non-null  str
#  2   product_name   501893 non-null  str
#  3   year           501893 non-null  int64
#  4   month          501893 non-null  int64
#  5   rating         501893 non-null  int64
#  6   helpful_count  501893 non-null  int64
#  7   has_image      501893 non-null  int64
#  8   cat1           501893 non-null  str
#  9   cat2           501893 non-null  str
#  10  brand          501893 non-null  str
# dtypes: float64(1), int64(5), str(5)
# memory usage: 81.7 MB

# %%
df_check[['brand', 'has_image']].head()
# Out:
#   brand  has_image
# 0  젝시믹스          1
# 1  젝시믹스          1
# 2  젝시믹스          1
# 3  젝시믹스          1
# 4  젝시믹스          1

# %% [markdown]
# ### 모델링 추출 데이터셋 확인

# %%
df_bert = pd.read_parquet(path + 'dashboard_reviews_110M.parquet')
df_absa = pd.read_parquet(path + 'absa_phase_e_predictions.parquet')

# %%
df_absa.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12056 entries, 0 to 12055
# Data columns (total 43 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   collect_date           12056 non-null  str
#  1   platform               12056 non-null  str
#  2   review_id              12056 non-null  float64
#  3   product_id             12056 non-null  str
#  4   product_name           12056 non-null  str
#  5   review_date            12056 non-null  str
#  6   year                   12056 non-null  int64
#  7   month                  12056 non-null  int64
#  8   content                12056 non-null  str
#  9   rating                 12056 non-null  int64
#  10  helpful_count          12056 non-null  int64
#  11  has_image              12056 non-null  int64
#  12  purchase_option        12056 non-null  str
#  13  purchase_option_color  12056 non-null  str
#  14  purchase_option_size   12056 non-null  str
# ...

# %%
df_absa.head()
# Out:
#   collect_date platform    review_id     product_id  \
# 0   2026-04-17      자사몰  361896950.0   prod20002583
# 1   2026-04-21      자사몰   36551446.0          10587
# 2   2026-04-20      자사몰    4505095.0        2075483
# 3   2026-04-20      자사몰    4273711.0        2077455
# 4   2026-04-28      자사몰     137521.0  8100359471140
#
#                       product_name review_date  year  month  \
# 0            저지 트레이닝 롱슬리브 셔츠 *워드마크  2025-10-14  2025     10
# 1                [1&1] 에어리핏 와이드 팬츠  2025-03-03  2025      3
# 2  블랙라벨 시그니처 파워라이즈 파이톤 배색 브라탑 살사레드  2025-03-22  2025      3
# 3      [2PACK] 매직밴딩 맨즈 슬랙스 9.1&9.6  2024-10-26  2024     10
# 4                     판테라 99/25 LX  2026-02-04  2026      2
#
#                                              content  rating  helpful_count  \
# 0  역시 편한한 데일리로 최고! 일단 원단이 저지원단이라 구김없고 편하고 소매도 시보리...       5              0
# 1  기장수선안해도 되고 맞춤으로 잘맞아요..주름가지았고 편하고 두루두루 자주 입을것 같...       5              0
# ...

# %%
df_bert.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1110129 entries, 0 to 1110128
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   brand       1110129 non-null  str
#  1   rating      1110129 non-null  int64
#  2   topic       1110129 non-null  int64
#  3   topic_name  1110129 non-null  str
#  4   aspect      676951 non-null   str
#  5   content     1110129 non-null  str
# dtypes: int64(2), str(4)
# memory usage: 312.5 MB

# %%
df_bert.head()
# Out:
#   brand  rating  topic              topic_name           aspect  \
# 0   안다르       5     28  [기능성] 릴렉스마사지, 시원하다, 스틱  aspect_function
# 1   안다르       3     -1              [노이즈] 분류불가              NaN
# 2   안다르       5     -1              [노이즈] 분류불가              NaN
# 3   안다르       5     28  [기능성] 릴렉스마사지, 시원하다, 스틱  aspect_function
# 4   안다르       5     28  [기능성] 릴렉스마사지, 시원하다, 스틱  aspect_function
#
#                                              content
# 0  러닝 후 몸 풀어주는 용으로 아주 좋아요. 종아리나 등, 목 뒤에 사용하기 좋아요....
# 1  딱딱하네요\n저는 말랑말랑 한줄 알았어요(2026-04-07 20:15:59 에 등...
# 2  요가링이랑 폼롤러랑 같이 사서 집에서 잘 굴려주고 있어요 색깔도 너무 예쁘고 귀여워...
# 3               묵직하니 사용하기 편하네요 릴렉스 마사지 듀얼볼 Ⅱ 후기 정사이즈
# 4  시원하게 마사지가되요 여기저기 쉽게 문지르고 아픈 부위 꾹꾹 눌러주니 시원하네요 릴...
