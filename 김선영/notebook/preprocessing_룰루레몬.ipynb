# %%
# 룰루레몬
df_review_lululemon_mss = pd.read_csv("/Users/kimsunyeong/Desktop/SPARTA_PROJECT_4TH_E_COMMERCE/김선영/data/reviews/musinsa_lululemon_reviews.csv", encoding='utf-8')
df_review_lululemon_D2C = pd.read_csv("/Users/kimsunyeong/Desktop/SPARTA_PROJECT_4TH_E_COMMERCE/김선영/data/reviews/lululemon_reviews_master_20260417.csv", encoding='utf-8')
